# %% [markdown]
# ### Prachee Prasad, 281060
# ## Assignment 2
#
# Visualize the data using R/Python by plotting the graphs for previous assignments.
#
# Consider
# suitable data set.
#
#  Use Scatter plot, Bar plot, Box plot, Pie chart, Line Chart.

# %%
#import libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#import data (heart.csv)
df = pd.read_csv('datasets/Heart.csv')
df.head()
# Out:
#    Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0           1   63    1       typical     145   233    1        2    150
# 1           2   67    1  asymptomatic     160   286    0        2    108
# 2           3   67    1  asymptomatic     120   229    0        2    129
# 3           4   37    1    nonanginal     130   250    0        0    187
# 4           5   41    0    nontypical     130   204    0        2    172
#
#    ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 0      0      2.3      3  0.0       fixed   No
# 1      1      1.5      2  3.0      normal  Yes
# 2      1      2.6      2  2.0  reversable  Yes
# 3      0      3.5      3  0.0      normal   No
# 4      0      1.4      1  0.0      normal   No

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.scatterplot(x='Age', y='MaxHR', hue='ChestPain', data=df, palette=['pink', 'yellow', 'lightblue', 'purple'])
plt.title('Scatter Plot')
plt.xlabel('Age')
plt.ylabel('MaxHR')
plt.show()

# %%
# implementing bar plot
plt.figure(figsize=(8, 6))
df['ChestPain'].value_counts().plot(kind='bar', color='pink')  
plt.title('Bar Plot: ChestPain Frequency')
plt.xlabel('ChestPain Type')
plt.ylabel('Frequency')
plt.show()

# %%
# implementing Box Plot
plt.figure(figsize=(8, 6))
sns.boxplot(y='Age', data=df, color='pink') 
plt.title('Box Plot')
plt.ylabel('Age')
plt.show()

# %%
# implementing pie chart
plt.figure(figsize=(8, 6))
colors = ['pink', 'yellow', 'lightpink', 'gold']  
plt.pie(df['Thal'].value_counts(), labels=df['Thal'].value_counts().index, autopct='%1.1f%%', colors=colors)
plt.title('Pie Chart')
plt.ylabel('')
plt.show()

# %%
# implementing line chart
AgeArr = np.array(df['Age'])
SortedAgeArr = np.sort(AgeArr)
plt.figure(figsize=(24, 6))
plt.plot(SortedAgeArr, df['Chol'], marker='o', linestyle='-', color='pink')  # Setting line color to pink
plt.title('Line Chart: Age vs. Cholesterol')
plt.xlabel('Age')
plt.ylabel('Cholesterol (Chol)')
plt.grid(True)
plt.show()
